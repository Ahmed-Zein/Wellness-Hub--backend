# %% [markdown]
# # Technology Stack and Tools
#
# ## 1. ExpressJs
#
# ## 2. MongoDB & Mongoose

# %% [markdown]
# # Security
#
# ## 1. Authentication
#
# - We Decided to Use JSON Web Tokens (JWT) a different approach to the traditional cookies/sessions
#
# ### Used Libraries :
#
# - jsonwebtoken
#
# <img href="img/auth.png">

# %%
# show authrized route
import  requests

url = "https://wellnesshub.onrender.com/api/v1";
body= {
	"seller": "6670d59acb32f53577025746",# fake user data
	"title": "Fake titel",
	"description": "Fake description",
		"images": [],
	"ingredients":[ ],
	"category":"appetizers",
    "price": 9999
}

res = requests.post(url+ "/meals", data=body)

if(res.status_code==401):
    raise Exception("401 NOT AUTHORIZED")

# %% [markdown]
# ## 2. DDOS
#
# We are using rate-limiting middleware to limit repeated requests to public APIs and/or endpoints such as registration
#
# ### Used Libraries :
#
# - express-rate-limit
#
# <img href="img/rate.png">
#
# ### Let's try:

# %%
# !npm run ddos

# %% [markdown]
# # API tree
#
# <div style="text-align: center;">
# <img src="img/apis.png" width=1000>
# </div>

# %% [markdown]
# # Tooling
#
# <div style="text-align: center;">
# <img src="img/insomania.png" width=800>
# </div>

# %% [markdown]
# # Logging System
#
# - Logging is Crucial for Observability and System reliability
#
#
# <div style="text-align: center;">
# <img src="img/loggin.png" width=1000>
# </div>

# %% [markdown]
# # Error Handling
#
# - we collect all the errors that occur in the backend and handle it in a special error handling middleware that takes care of logging the error and sends the response containing the error message to the user.
#
# ```js
# app.use((err, req, res, next) => {
#   const statusCode = err.statusCode || res.statusCode || 500;
#   logger.error(
#     `error: ${err.message}, code: ${statusCode}, type: ${err.type || "na"}`
#   );
#   res.status(statusCode).send({ error: err.message });
# });
# ```
#
# - And We wrote our own custom erro handling to help us track and log the different types of erros that occur in the code
#
# ```js
# class CustomError extends Error {
#   constructor(msg, type, statusCode) {
#     super(msg);
#     this.type = type;
#     this.statusCode = statusCode;
#   }
# }
# ```
#
# and defined our own ErrorTypes which masks the error messaga that gets logged in the final error middleware
#
# ```js
# const ErrorTypes = module.exports;
#
# ErrorTypes.AuthError = "Authentication Error";
#
# ErrorTypes.ServerError = "Server Error";
#
# ErrorTypes.UnAuthorizedAccess = "unauthorized access Error";
#
# ErrorTypes.NotFoundError = "Not found Error";
#
# ErrorTypes.BadRequestError = "Bad Request";
#
# ErrorTypes.Conflict = "Confilct";
#
# ErrorTypes.UnprocessableEntity =
#   "The server was unable to process the request because it contains invalid data";
# ```

# %% [markdown]
# # Unit tests

# %%
# !npm test
# Out:
# > wellnes-hub@1.0.0 test
# > NODE_ENV=test jest
#
# Determining test suites to run...
#
# Test Suites: 0 of 5 total
# Tests:       0 total
# Snapshots:   0 total
# Time:        0 s, estimated 8 s
# 37m███████████████████████████████████████
#
# Test Suites: 0 of 5 total
# Tests:       0 total
# Snapshots:   0 total
# Time:        0 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       0 total
# Snapshots:   0 total
# Time:        0 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       0 total
# Snapshots:   0 total
# Time:        1 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       0 total
# Snapshots:   0 total
# Time:        2 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       1 passed, 1 total
# Snapshots:   0 total
# Time:        2 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       1 passed, 1 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# POST /api/v1/customer/register 201 615.867 ms - 436█████████████████████████████████
# POST /api/v1/Seller/register 201 586.067 ms - 240
# GET /api/v1/customer/65d249efb0caf340385287fb 404 31.799 ms - 29
# POST /api/v1/customer/register 201 565.315 ms - 436
# POST /api/v1/meals 201 23.373 ms - 349
# POST /api/v1/seller/register 201 607.701 ms - 240
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       1 passed, 1 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       6 passed, 6 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# POST /api/v1/customer/register 409 39.251 ms - 31m██████████████████████████████████
# POST /api/v1/customer/register 201 615.881 ms - 436
# POST /api/v1/seller/register 409 26.224 ms - 33
# GET /api/v1/customer/6678c4b8951bf45f545bcf8c/weekplan 200 17.487 ms - 722
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       6 passed, 6 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# POST /api/v1/customer/register 201 482.107 ms - 436█████████████████████████████████
# GET /api/v1/customer/6678c4b8c555c9db7e64c77d 200 8.548 ms - 142
# POST /api/v1/Seller/register 201 481.244 ms - 240
# POST /api/v1/meals 403 22.417 ms - 77
# POST /api/v1/customer/register 201 496.252 ms - 436
# POST /api/v1/customer/register 422 1.976 ms - 152
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       6 passed, 6 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       9 passed, 9 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# POST /api/v1/seller/register 201 503.723 ms - 240m██████████████████████████████████
# POST /api/v1/seller/register 422 3.561 ms - 24
# POST /api/v1/customer/register 201 529.777 ms - 436
# POST /api/v1/customer/6678c4b9951bf45f545bcf9f/weekplan 200 21.211 ms - 762
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       9 passed, 9 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       11 passed, 11 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
#  PASS  __test__/customer/weekplan.test.js███████████████████████████████
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#  RUNS  __test__/customer/weekplan.test.js
#
# Test Suites: 0 of 5 total
# Tests:       11 passed, 11 total
# Snapshots:   0 total
# Time:        3 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#
# Test Suites: 1 passed, 1 of 5 total
# Tests:       11 passed, 11 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
# POST /api/v1/customer/register 201 541.391 ms - 436█████████████████████████████████
# POST /api/v1/customer/65d249edb0caf340385287fb/wishlist/65d249efb9caf340385287fb 404 5.826 ms - 30
# POST /api/v1/Seller/register 201 512.317 ms - 240
# POST /api/v1/meals 201 9.467 ms - 349
# GET /api/v1/meals/ 200 5.424 ms - 315
# POST /api/v1/customer/register 201 541.893 ms - 436
# POST /api/v1/seller/register 201 533.606 ms - 240
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#
# Test Suites: 1 passed, 1 of 5 total
# Tests:       11 passed, 11 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#
# Test Suites: 1 passed, 1 of 5 total
# Tests:       13 passed, 13 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
#  PASS  __test__/customer/customer.test.js███████████████████████████████
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#
# Test Suites: 1 passed, 1 of 5 total
# Tests:       13 passed, 13 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
#   ● Console32m██████████████████████████████████████
#
#     console.log
#       error:   error: user id not found, code: 404, type: Not found Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: customer not found, code: 404, type: Not found Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: item id not found, code: 404, type: Not found Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#
# Test Suites: 1 passed, 1 of 5 total
# Tests:       13 passed, 13 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
# POST /api/v1/customer/register 201 490.383 ms - 436█████████████████████████████████
# POST /api/v1/Seller/register 201 474.487 ms - 240
# POST /api/v1/customer/6678c4b9c555c9db7e64c79c/wishlist/65d249efb9caf340385287fb 404 8.066 ms - 29
# POST /api/v1/customer/login 200 452.085 ms - 436
# POST /api/v1/meals 201 11.562 ms - 349
# GET /api/v1/meals/6678c4b965c7a74359270240 200 4.417 ms - 313
# POST /api/v1/seller/login 200 480.416 ms - 436
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#  RUNS  __test__/customer/customer.test.js
#
# Test Suites: 1 passed, 1 of 5 total
# Tests:       13 passed, 13 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#
# Test Suites: 2 passed, 2 of 5 total
# Tests:       17 passed, 17 total
# Snapshots:   0 total
# Time:        4 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#
# Test Suites: 2 passed, 2 of 5 total
# Tests:       17 passed, 17 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
#  PASS  __test__/meals/meals.test.js (5.124 s)9m████████████████████████████
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#
# Test Suites: 2 passed, 2 of 5 total
# Tests:       17 passed, 17 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
#   ● Console32m██████████████████████████████████████
#
#     console.log
#       error:   error: seller id in the body does not match the seller in the auth token, code: 403, type: unauthorized access Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: meal not found, code: 404, type: Not found Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#
# Test Suites: 2 passed, 2 of 5 total
# Tests:       17 passed, 17 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
# POST /api/v1/Seller/register 201 467.125 ms - 240m██████████████████████████████████
# POST /api/v1/customer/register 201 486.752 ms - 436
# POST /api/v1/meals 201 8.395 ms - 349
# POST /api/v1/seller/register 201 454.427 ms - 240
# GET /api/v1/meals/6670d59acb32f53577025746 404 6.740 ms - 26
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#  RUNS  __test__/meals/meals.test.js
#
# Test Suites: 2 passed, 2 of 5 total
# Tests:       17 passed, 17 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       18 passed, 18 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
# POST /api/v1/customer/login 401 465.124 ms - 2632m██████████████████████████████████
# POST /api/v1/seller/login 401 464.182 ms - 26
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       18 passed, 18 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       20 passed, 20 total
# Snapshots:   0 total
# Time:        5 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       20 passed, 20 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
#  PASS  __test__/customer/auth.test.js (6.054 s)████████████████████████████
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       20 passed, 20 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
#   ● Console32m██████████████████████████████████████
#
#     console.log
#       error:   error: user already exists, code: 409, type: Authentication Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: wrong password, code: 401, type: unauthorized access Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: email does not exist, code: 404, type: Authentication Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       20 passed, 20 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
# POST /api/v1/customer/register 201 461.907 ms - 436█████████████████████████████████
# POST /api/v1/customer/login 404 4.193 ms - 32
# POST /api/v1/seller/register 201 464.014 ms - 240
# POST /api/v1/seller/login 404 4.834 ms - 32
#
#  RUNS  __test__/seller/seller-auth.test.js
#  RUNS  __test__/customer/auth.test.js
#
# Test Suites: 3 passed, 3 of 5 total
# Tests:       20 passed, 20 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#
# Test Suites: 4 passed, 4 of 5 total
# Tests:       22 passed, 22 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
# POST /api/v1/Seller/register 201 449.079 ms - 240m██████████████████████████████████
# GET /api/v1/Seller/65d249efb0caf340385287fb 404 3.389 ms - 28
#
#  RUNS  __test__/seller/seller-auth.test.js
#
# Test Suites: 4 passed, 4 of 5 total
# Tests:       22 passed, 22 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#
# Test Suites: 4 passed, 4 of 5 total
# Tests:       23 passed, 23 total
# Snapshots:   0 total
# Time:        6 s, estimated 8 s
# m████████████████████████████████████████
#  RUNS  __test__/seller/seller-auth.test.js
#
# Test Suites: 4 passed, 4 of 5 total
# Tests:       23 passed, 23 total
# Snapshots:   0 total
# Time:        7 s, estimated 8 s
#  PASS  __test__/seller/seller-auth.test.js (6.974 s)████████████████████████████
#
#  RUNS  __test__/seller/seller-auth.test.js
#
# Test Suites: 4 passed, 4 of 5 total
# Tests:       23 passed, 23 total
# Snapshots:   0 total
# Time:        7 s, estimated 8 s
#   ● Console32m██████████████████████████████████████
#
#     console.log
#       error:   error: seller already exists, code: 409, type: Authentication Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: missing data, code: 422, type: The server was unable to process the request because it contains invalid data
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: wrong password, code: 401, type: unauthorized access Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: email does not exist, code: 404, type: Authentication Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#     console.log
#       error:   error: Seller not found, code: 404, type: Not found Error
#
#       at Console.log (node_modules/winston/lib/winston/transports/console.js:79:23)
#
#
#  RUNS  __test__/seller/seller-auth.test.js
#
# Test Suites: 4 passed, 4 of 5 total
# Tests:       23 passed, 23 total
# Snapshots:   0 total
# Time:        7 s, estimated 8 s
# Running coverage on untested files...32m██████████████████████████████████POST /api/v1/Seller/register 201 443.957 ms - 240
# GET /api/v1/Seller/6678c4bc36e63ebc83cb8c70 200 3.327 ms - 128
# -------------------|---------|----------|---------|---------|-------------------
# File               | % Stmts | % Branch | % Funcs | % Lines | Uncovered Line #s
# -------------------|---------|----------|---------|---------|-------------------
# All files          |   27.52 |     9.67 |    17.6 |   44.15 |
#  ...s-Hub--backend |      78 |    28.57 |      20 |      78 |
#   app.js           |       0 |        0 |       0 |       0 | 1-12
#   jest.config.js   |       0 |      100 |     100 |       0 | 4
#   server.js        |   95.12 |       40 |   33.33 |   95.12 | 36,40
#  ...ge/lcov-report |       0 |        0 |       0 |       0 |
#   ...navigation.js |       0 |        0 |       0 |       0 | 2-87
#   prettify.js      |       0 |        0 |       0 |       0 | 2
#   sorter.js        |       0 |        0 |       0 |       0 | 2-196
#  ...--backend/demo |       0 |        0 |       0 |       0 |
#   ddos.js          |       0 |        0 |       0 |       0 | 1-14
#  ...d/src/checkout |   39.13 |        0 |       0 |   39.13 |
#   stripe.js        |   39.13 |        0 |       0 |   39.13 | 9,13-53
#  ...end/src/common |   71.25 |    61.53 |   81.81 |   72.15 |
#   auth.js          |      92 |    83.33 |     100 |      92 | 17-18
#   jwt.js           |      75 |       70 |     100 |   78.94 | 10,25-27
#   logger.js        |     100 |      100 |     100 |     100 |
#   middlewares.js   |   91.66 |      100 |   66.66 |   91.66 | 21
#   utils.js         |      25 |       25 |      50 |      25 | 21-51
#  ...d/src/customer |      53 |    30.76 |   31.57 |   54.49 |
#   ...controller.js |    8.92 |        0 |       0 |    8.92 | ...24,31-65,72-98
#   ...controller.js |   65.34 |    57.14 |   46.15 |   68.75 | ...72,182,192,200
#   ...omer.model.js |     100 |      100 |     100 |     100 |
#   ...mer.routes.js |     100 |      100 |     100 |     100 |
#  ...end/src/errors |     100 |      100 |     100 |     100 |
#   customerError.js |     100 |      100 |     100 |     100 |
#   error-types.js   |     100 |      100 |     100 |     100 |
#  ...kend/src/event |   33.33 |        0 |       0 |   33.33 |
#   event.model.js   |     100 |      100 |     100 |     100 |
#   event.routes.js  |   25.71 |        0 |       0 |   25.71 | ...29,35-52,58-67
#  ...d/src/feedback |   45.45 |      100 |       0 |   45.45 |
#   ...back.model.js |     100 |      100 |     100 |     100 |
#   ...ack.routes.js |   36.84 |      100 |       0 |   36.84 | 8-13,21-34
#  ...kend/src/meals |   57.65 |    17.85 |    37.5 |   57.65 |
#   ....contoller.js |   53.44 |    22.72 |      60 |   53.44 | ...6,63-79,84-109
#   meal.model.js    |     100 |      100 |     100 |     100 |
#   meal.routes.js   |     100 |      100 |     100 |     100 |
#   ...controller.js |   23.07 |        0 |       0 |   23.07 | 6-21,26-43,48-65
#  ...kend/src/order |   31.37 |        0 |       0 |   32.65 |
#   order.model.js   |     100 |      100 |     100 |     100 |
#   order.routes.js  |   25.53 |        0 |       0 |   26.66 | ...24,30-36,41-83
#  ...nd/src/product |   17.18 |        0 |       0 |   17.32 |
#   ...controller.js |       0 |        0 |       0 |       0 |
#   product.model.js |   38.46 |        0 |       0 |   41.66 | 23,65-66,71-74
#   ...uct.routes.js |   14.78 |        0 |       0 |   14.78 | ...68-189,199-223
#  ...nd/src/recipes |   33.33 |        0 |       0 |   34.21 |
#   recipe.model.js  |   38.46 |        0 |       0 |   41.66 | 39,77-78,83-86
#   recipe.routes.js |   30.76 |        0 |       0 |   30.76 | 8-13,19-26,32-54
#  ...end/src/seller |   97.95 |    91.66 |     100 |   97.95 |
#   ...controller.js |   96.55 |    91.66 |     100 |   96.55 | 28
#   seller.model.js  |     100 |      100 |     100 |     100 |
#   seller.routes.js |     100 |      100 |     100 |     100 |
# -------------------|---------|----------|---------|---------|-------------------
#
# Test Suites: 5 passed, 5 total
# Tests:       24 passed, 24 total
# Snapshots:   0 total
# Time:        8.506 s
# Ran all test suites.
# ⠙

# %% [markdown]
# # Production Pipeline
#
# <!-- ![alt text](img/pipline.png) -->
#
# <div style="text-align: center;">
# <img src="img/pipline.png" width=1000>
# </div>
#
# ## Triggering github action to run

# %%
# !touch test.txt && git add . && git commit -m "should trigger actions to build"
# git push
# Out:
# [master 3358271] should trigger actions to build
#  1 file changed, 278 insertions(+), 1064 deletions(-)
#  rewrite demo/demp.ipynb (94%)

# %%
# !docker build -t ahmedzein/wellness ../
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             0.5s
# [+] Building 0.6s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             0.6s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             0.8s
# [+] Building 0.9s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             0.9s
# [+] Building 1.1s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             1.1s
# [+] Building 1.2s (1/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             1.2s
# [+] Building 1.3s (2/2)                                          docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             1.3s
# [+] Building 1.5s (10/10)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             1.3s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2.18kB                                        0.0s
#  => [1/6] FROM docker.io/library/node:alpine@sha256:6a9d796ae64c80fd1cc66  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 440.56kB                                      0.0s
#  => CACHED [2/6] WORKDIR /user/src/app                                     0.0s
#  => CACHED [3/6] COPY package.json  .                                      0.0s
#  => CACHED [4/6] COPY package-lock.json .                                  0.0s
#  => CACHED [5/6] RUN npm i                                                 0.0s
#  => [6/6] COPY . .                                                         0.1s
# [+] Building 1.6s (11/11)                                        docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             1.3s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2.18kB                                        0.0s
#  => [1/6] FROM docker.io/library/node:alpine@sha256:6a9d796ae64c80fd1cc66  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 440.56kB                                      0.0s
#  => CACHED [2/6] WORKDIR /user/src/app                                     0.0s
#  => CACHED [3/6] COPY package.json  .                                      0.0s
#  => CACHED [4/6] COPY package-lock.json .                                  0.0s
#  => CACHED [5/6] RUN npm i                                                 0.0s
#  => [6/6] COPY . .                                                         0.1s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
#  => => writing image sha256:6f018a6959f06225d2c3a7f4fab0b19fd948d1b8cc4c9  0.0s
#  => => naming to docker.io/ahmedzein/wellness                              0.0s
# [+] Building 1.7s (11/11) FINISHED                               docker:default
#  => [internal] load build definition from dockerfile                       0.0s
#  => => transferring dockerfile: 183B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:alpine             1.3s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2.18kB                                        0.0s
#  => [1/6] FROM docker.io/library/node:alpine@sha256:6a9d796ae64c80fd1cc66  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 440.56kB                                      0.0s
#  => CACHED [2/6] WORKDIR /user/src/app                                     0.0s
#  => CACHED [3/6] COPY package.json  .                                      0.0s
#  => CACHED [4/6] COPY package-lock.json .                                  0.0s
#  => CACHED [5/6] RUN npm i                                                 0.0s
#  => [6/6] COPY . .                                                         0.1s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
#  => => writing image sha256:6f018a6959f06225d2c3a7f4fab0b19fd948d1b8cc4c9  0.0s
#  => => naming to docker.io/ahmedzein/wellness                              0.0s

# %%
# !docker image ls | grep -E 'REPOSITORY|ahmedzein/wellness'
# Out:
# REPOSITORY           TAG       IMAGE ID       CREATED             SIZE
# ahmedzein/wellness   latest    6f018a6959f0   4 seconds ago       237MB

# %% [markdown]
# # Deployment
#
# We use docker to containerize our app and host our app image on docker hub which provides a hook which is used to trigger Render our cloud service to use the latest snapshot on docker-Hub.
#
# <div style="text-align: center;">
# <img src="img/archi.png" width=700>
# </div>

# %% [markdown]
# # Disclaimer
#
# This is the effort of real human beings and all is done without chaggpt or any other LLMs
